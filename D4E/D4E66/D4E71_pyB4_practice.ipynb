# %%
import pandas as pd

# %% [markdown]
# # đọc dữ liệu 3 file vừa down và gán chúng nó và 3 biến df1, df2 ,df3

# %%
df1 = pd.read_csv(r"D:\Work\MindX\D4E\mexico-real-estate-1.csv")
df2 = pd.read_csv(r"D:\Work\MindX\D4E\mexico-real-estate-2.csv")
df3 = pd.read_csv(r"D:\Work\MindX\D4E\mexico-real-estate-3.csv")

# %% [markdown]
# ### df1:
# - price_usd: xóa dầu $, dấu ',' : replace
# - chuyển kiểu dữ liệu về float: astype

# %%
df1
# Out:
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# 695         house                          Morelos        NaN         NaN
# 696         house                          Yucatán  21.050653  -89.558841
# 697         house                          Yucatán  21.343796  -89.262060
# 698     apartment                       Nuevo León        NaN         NaN
# 699         house                        Querétaro  20.587378 -100.418361
#
#      area_m2    price_usd
# 0      150.0   $67,965.56
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_usd      700 non-null    object
# dtypes: float64(3), object(3)
# memory usage: 32.9+ KB

# %%
df1['price_usd'] = df1['price_usd'].str.replace('$','').str.replace(',','').astype('float')
df1
# Out:
# C:\Users\dk201\AppData\Local\Temp\ipykernel_28968\1153953382.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df1['price_usd'] = df1['price_usd'].str.replace('$','').str.replace(',','').astype('float')
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# 695         house                          Morelos        NaN         NaN
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            583 non-null    float64
#  3   lon            583 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_usd      700 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 32.9+ KB

# %%
df1.describe()
# Out:
#               lat         lon     area_m2      price_usd
# count  583.000000  583.000000  700.000000     700.000000
# mean    20.677211  -98.394698  171.708571  115989.660386
# std      2.563123    4.797798   78.267786   66074.073821
# min     16.717077 -117.033916   60.000000   33358.450000
# 25%     19.198379 -100.344878  105.750000   65858.100000
# 50%     19.559799  -99.180214  160.000000   98590.075000
# 75%     21.096664  -97.911407  220.000000  148106.782500
# max     32.665619  -86.767539  385.000000  326733.660000

# %% [markdown]
# ### df2: price_mxn: đổi tên thành price_usd
# - rename
# - Quy đổi tiền tệ

# %%
df2
# Out:
#     property_type             state        lat         lon  area_m2  price_mxn
# 0       apartment        Nuevo León  25.721081 -100.345581     72.0  1300000.0
# 1       apartment            Puebla        NaN         NaN    190.0  2500000.0
# 2           house           Morelos  23.634501 -102.552788    360.0  5300000.0
# 3           house           Morelos        NaN         NaN     76.0   820000.0
# 4           house            Puebla        NaN         NaN    200.0  1100000.0
# ..            ...               ...        ...         ...      ...        ...
# 695         house           Morelos  18.917542  -98.963181    140.0  1450000.0
# 696         house  Distrito Federal  19.472128  -99.146697    190.0  1943000.0
# 697         house  Estado de México  19.234984  -99.558175    115.0  2100000.0
# 698         house            Puebla  18.918714  -98.426639     90.0   890000.0
# 699         house           Yucatán  21.075163  -89.516731    185.0  1695000.0
#
# [700 rows x 6 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            571 non-null    float64
#  3   lon            571 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_mxn      700 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 32.9+ KB

# %%
df2.describe()
# Out:
#               lat         lon     area_m2     price_mxn
# count  571.000000  571.000000  700.000000  7.000000e+02
# mean    20.983555  -99.012350  173.754286  2.190765e+06
# std      2.959004    5.227166   78.535211  1.237497e+06
# min     16.228815 -117.038495   60.000000  6.260000e+05
# 25%     19.287224 -100.442642  110.000000  1.250000e+06
# 50%     20.302476  -99.201675  160.000000  1.850000e+06
# 75%     21.156042  -98.244797  224.250000  2.835750e+06
# max     32.647057  -86.817017  385.000000  6.100000e+06

# %%
df2.rename(columns={'price_mxn':'price_usd'},inplace=True)
# df2['price_usd'] = df2['price_usd'] / 16.96
df2['price_usd'] = df2['price_usd'] * 0.059
df2
# Out:
#     property_type             state        lat         lon  area_m2  price_usd
# 0       apartment        Nuevo León  25.721081 -100.345581     72.0    76700.0
# 1       apartment            Puebla        NaN         NaN    190.0   147500.0
# 2           house           Morelos  23.634501 -102.552788    360.0   312700.0
# 3           house           Morelos        NaN         NaN     76.0    48380.0
# 4           house            Puebla        NaN         NaN    200.0    64900.0
# ..            ...               ...        ...         ...      ...        ...
# 695         house           Morelos  18.917542  -98.963181    140.0    85550.0
# 696         house  Distrito Federal  19.472128  -99.146697    190.0   114637.0
# 697         house  Estado de México  19.234984  -99.558175    115.0   123900.0
# 698         house            Puebla  18.918714  -98.426639     90.0    52510.0
# 699         house           Yucatán  21.075163  -89.516731    185.0   100005.0
#
# [700 rows x 6 columns]

# %%
df2.describe()
# Out:
#               lat         lon     area_m2      price_usd
# count  571.000000  571.000000  700.000000     700.000000
# mean    20.983555  -99.012350  173.754286  129255.115783
# std      2.959004    5.227166   78.535211   73012.350987
# min     16.228815 -117.038495   60.000000   36934.000000
# 25%     19.287224 -100.442642  110.000000   73750.000000
# 50%     20.302476  -99.201675  160.000000  109150.000000
# 75%     21.156042  -98.244797  224.250000  167309.250000
# max     32.647057  -86.817017  385.000000  359900.000000

# %%
# df2.set_axis(['property_type', 'state', 'lat', 'lon', 'area_m2', 'price'],axis=1,inplace=False)

# %% [markdown]
# ### df3:
# - place_with_parent_names: tách dữ liệu và lấy cột state => split
# - lat-lon: tách dữ liệu làm 2 cột lat lon => split

# %%
df3
# Out:
#     property_type                            place_with_parent_names  \
# 0       apartment  |México|Distrito Federal|Gustavo A. Madero|Acu...
# 1           house           |México|Estado de México|Toluca|Metepec|
# 2           house  |México|Estado de México|Toluca|Toluca de Lerd...
# 3           house        |México|Morelos|Temixco|Burgos Bugambilias|
# 4       apartment  |México|Veracruz de Ignacio de la Llave|Veracruz|
# ..            ...                                                ...
# 695         house  |México|Jalisco|Tlajomulco de Zúñiga|Tlajomulc...
# 696         house                          |México|Morelos|Jiutepec|
# 697         house                            |México|Yucatán|Mérida|
# 698         house           |México|San Luis Potosí|San Luis Potosí|
# 699         house           |México|Estado de México|Toluca|Metepec|
#
#                           lat-lon  area_m2  price_usd
# 0             19.52589,-99.151703     71.0   48550.59
# ...

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       700 non-null    object
#  1   1       700 non-null    object
#  2   2       700 non-null    object
#  3   3       700 non-null    object
#  4   4       693 non-null    object
#  5   5       171 non-null    object
#  6   6       32 non-null     object
# dtypes: object(7)
# memory usage: 38.4+ KB

# %%
df3['state'] = df3['place_with_parent_names'].str.split('|',expand=True)[3]
df3['lat'] = df3['lat-lon'].str.split(',',expand=True)[0].astype('float')
df3['lon'] = df3['lat-lon'].str.split(',',expand=True)[1].astype('float')
df31 = df3[['property_type', 'state','lat','lon','area_m2','price_usd']]
df31
# Out:
#     property_type                 state        lat         lon  area_m2  \
# 0       apartment     Gustavo A. Madero  19.525890  -99.151703     71.0
# 1           house                Toluca  19.264054  -99.572753    233.0
# 2           house                Toluca  19.268629  -99.671722    300.0
# 3           house               Temixco        NaN         NaN    275.0
# 4       apartment              Veracruz  19.511938  -96.871956     84.0
# ..            ...                   ...        ...         ...      ...
# 695         house  Tlajomulco de Zúñiga  20.532264 -103.484418    175.0
# 696         house              Jiutepec  18.928986  -99.180215    100.0
# 697         house                Mérida  21.028404  -89.653006     81.0
# 698         house       San Luis Potosí  22.118304 -101.032194    360.0
# 699         house                Toluca  19.233201  -99.558519    115.0
#
#      price_usd
# 0     48550.59
# 1    168636.73
# 2     86932.69
# 3    263432.41
# 4     68508.67
# ...

# %%
df31.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  700 non-null    object
#  1   state          700 non-null    object
#  2   lat            582 non-null    float64
#  3   lon            582 non-null    float64
#  4   area_m2        700 non-null    float64
#  5   price_usd      700 non-null    float64
# dtypes: float64(4), object(2)
# memory usage: 32.9+ KB

# %%
c1 = df1.append(df2)
c1 = c1.append(df31)
c1
# Out:
# C:\Users\dk201\AppData\Local\Temp\ipykernel_28968\1761375776.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c1 = df1.append(df2)
# C:\Users\dk201\AppData\Local\Temp\ipykernel_28968\1761375776.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   c1 = c1.append(df31)
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# ...

# %%
c2 = pd.concat([df1,df2])
c2 = pd.concat([c2,df31])
c2
# Out:
#     property_type                            state        lat         lon  \
# 0           house                 Estado de México  19.560181  -99.233528
# 1           house                       Nuevo León  25.688436 -100.198807
# 2       apartment                         Guerrero  16.767704  -99.764383
# 3       apartment                         Guerrero  16.829782  -99.911012
# 4           house  Veracruz de Ignacio de la Llave        NaN         NaN
# ..            ...                              ...        ...         ...
# 695         house             Tlajomulco de Zúñiga  20.532264 -103.484418
# 696         house                         Jiutepec  18.928986  -99.180215
# 697         house                           Mérida  21.028404  -89.653006
# 698         house                  San Luis Potosí  22.118304 -101.032194
# 699         house                           Toluca  19.233201  -99.558519
#
#      area_m2  price_usd
# 0      150.0   67965.56
# 1      186.0   63223.78
# ...

# %%
c2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2100 entries, 0 to 699
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   property_type  2100 non-null   object
#  1   state          2100 non-null   object
#  2   lat            1736 non-null   float64
#  3   lon            1736 non-null   float64
#  4   area_m2        2100 non-null   float64
#  5   price_usd      2100 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 114.8+ KB

# %%
c2.isnull().sum()
# Out:
# property_type      0
# state              0
# lat              364
# lon              364
# area_m2            0
# price_usd          0
# dtype: int64

# %%
c2.describe()
# Out:
#                lat          lon      area_m2      price_usd
# count  1736.000000  1736.000000  2100.000000    2100.000000
# mean     20.765410   -98.798575   173.022857  121842.409880
# std       2.743425     4.882553    79.736156   69411.614557
# min      15.752900  -117.054763    60.000000   33192.480000
# 25%      19.275200  -100.392553   105.000000   68235.235000
# 50%      19.620518   -99.204001   160.000000  104756.050000
# 75%      21.073428   -98.245911   223.000000  158096.930000
# max      32.665619   -86.767539   385.000000  359900.000000

# %%
import seaborn as sns

sns.boxplot( x=c2["property_type"], y=c2["price_usd"])
# Out:
# <Axes: xlabel='property_type', ylabel='price_usd'>

# %%
import seaborn as sns

sns.violinplot( x=c2["property_type"], y=c2["price_usd"])
# Out:
# <Axes: xlabel='property_type', ylabel='price_usd'>

# %%
sns.distplot( a=c2[c2['property_type']=='house']["price_usd"], hist=True)
# Out:
# C:\Users\dk201\AppData\Local\Temp\ipykernel_28968\2912515713.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( a=c2[c2['property_type']=='house']["price_usd"], hist=True)
# <Axes: xlabel='price_usd', ylabel='Density'>

# %%
sns.distplot( a=c2[c2['property_type']=='apartment']["price_usd"], hist=True)
# Out:
# C:\Users\dk201\AppData\Local\Temp\ipykernel_28968\2314812642.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot( a=c2[c2['property_type']=='apartment']["price_usd"], hist=True)
# <Axes: xlabel='price_usd', ylabel='Density'>
