# %%
import pandas as pd

# %%
def values_show(x):
    return list(set(x))

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTgQfVdqjCcmQpx9KTBxv-47cbuzq035YMq47Awd889gpIMAlpBlxGqH4ZTBXtPvg/pub?output=csv')
df['InvoiceDate'] = df['InvoiceDate'].str.split(' ', expand=True)[0]
df['month'] = df['InvoiceDate'].str.split('/', expand=True)[0]
df['day'] = df['InvoiceDate'].str.split('/', expand=True)[1]
df['year'] = df['InvoiceDate'].str.split('/', expand=True)[2].replace('10','2010').replace('11','2011')
df['date'] = df['year'] + '-' + df['month'] +'-'+ df['day']
df['date'] = pd.to_datetime(df['date'], format='%Y-%m-%d')
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate UnitPrice  CustomerID         Country month day  year  \
# ...

# %%
df1 = df[['date','CustomerID']].drop_duplicates()
df1.reset_index(drop=True,inplace=True)
# df1.set_index('date',inplace=True)
df1
# Out:
#             date  CustomerID
# 0     2010-12-01     17850.0
# 1     2010-12-01     13047.0
# 2     2010-12-01     12583.0
# 3     2010-12-01     13748.0
# 4     2010-12-01     15100.0
# ...          ...         ...
# 19568 2011-12-09     12748.0
# 19569 2011-12-09     13777.0
# 19570 2011-12-09     15804.0
# 19571 2011-12-09     13113.0
# 19572 2011-12-09     12680.0
#
# [19573 rows x 2 columns]

# %%
df1[df1['CustomerID']==12347]
# Out:
#             date  CustomerID
# 496   2010-12-07     12347.0
# 2341  2011-01-26     12347.0
# 5378  2011-04-07     12347.0
# 8413  2011-06-09     12347.0
# 10886 2011-08-02     12347.0
# 16033 2011-10-31     12347.0
# 19401 2011-12-07     12347.0

# %%
# cols = list(set(df['date'].astype('str')))
# cols.insert(0,'CustomerID')
# listd = pd.DataFrame(columns=cols)
# list1 = pd.DataFrame(values_show(df1[df1['date']=='2010-12-01']['CustomerID']), columns=['CustomerID'])
# list1 = pd.concat([list1,listd], ignore_index=True)
# list1

# %%
df2 = df1.groupby(['CustomerID'])[['date']].count()
df2
# Out:
#             date
# CustomerID
# 12346.0        1
# 12347.0        7
# 12348.0        4
# 12349.0        1
# 12350.0        1
# ...          ...
# 18280.0        1
# 18281.0        1
# 18282.0        3
# 18283.0       14
# 18287.0        3
#
# [4372 rows x 1 columns]

# %%
df2[df2['date']==1]
# Out:
#             date
# CustomerID
# 12346.0        1
# 12349.0        1
# 12350.0        1
# 12353.0        1
# 12354.0        1
# ...          ...
# 18262.0        1
# 18268.0        1
# 18278.0        1
# 18280.0        1
# 18281.0        1
#
# [1381 rows x 1 columns]

# %%
df3 = df2[df2['date']>1].sort_values(by='date',ascending=False)
df3
# Out:
#             date
# CustomerID
# 14911.0      146
# 12748.0      115
# 17841.0      113
# 15311.0       91
# 14606.0       89
# ...          ...
# 14481.0        2
# 14479.0        2
# 14474.0        2
# 14473.0        2
# 15221.0        2
#
# [2991 rows x 1 columns]

# %%
import plotly.express as px 
from plotly.subplots import make_subplots
import plotly.graph_objects as go

# %%
df = px.data.tips()
fig = px.violin(df3, y="date")
fig.show()

# %%
df4 = df1.groupby(['date'])[['date','CustomerID']].count().unstack().reset_index()
# df4.loc['Column_Total']= df4.sum(numeric_only=True, axis=0)
# df4.loc[:,'Row_Total'] = df4.sum(numeric_only=True, axis=1)
df4
# Out:
#         level_0       date    0
# 0          date 2010-12-01   99
# 1          date 2010-12-02  118
# 2          date 2010-12-03   56
# 3          date 2010-12-05   77
# 4          date 2010-12-06   91
# ..          ...        ...  ...
# 605  CustomerID 2011-12-05  114
# 606  CustomerID 2011-12-06  128
# 607  CustomerID 2011-12-07  101
# 608  CustomerID 2011-12-08  120
# 609  CustomerID 2011-12-09   38
#
# [610 rows x 3 columns]

# %%
# df1 = df.copy()
# df1['InvoiceDate'] = df['InvoiceDate'].apply(lambda x: x.replace(x[2:8],'{}/2010'.format(x[2:5])) if x[2:8] == '{}/10'.format(x[2:5]) else 
                                                       
#                                                        x.replace(x[5:8],'2011') if x[5:8] == '11' else 'error')
# df1
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#        InvoiceDate UnitPrice  CustomerID         Country month day  year  \
# ...

# %%
# df['InvoiceDate'][390034][2:5]
# Out:
# '/10'

# %%
# df['InvoiceDate'][390034][2:8]
# Out:
# '/10/11'

# %%
# df1[df1['InvoiceDate'].str.contains('2010/2010')]
# Out:
# Empty DataFrame
# Columns: [InvoiceNo, StockCode, Description, Quantity, InvoiceDate, UnitPrice, CustomerID, Country]
# Index: []
